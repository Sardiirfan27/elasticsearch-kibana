# %%
# !pip3 install psycopg2-binary

# %% [markdown]
# - [install postgresql](https://mcengkuru.medium.com/how-to-install-psql-on-your-mac-a-step-by-step-guide-with-troubleshooting-tips-ade65c441abf)

# %%
import pandas as pd
import psycopg2 as db
from elasticsearch import Elasticsearch

conn_string="dbname='postgres' host='localhost' user='postgres' password='12345678'"
conn=db.connect(conn_string)

df=pd.read_sql("select * from car_assignment", conn)
df.to_csv('postgresqldata.csv')
print("-------Data Saved------")
# Out:
# -------Data Saved------
# /var/folders/2g/khfzbcm51hj5wtq1k8bww50w0000gn/T/ipykernel_1725/2490292941.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql("select * from car_assignment", conn)

# %%
es = Elasticsearch(hosts="http://localhost:9200") 
df=pd.read_csv('postgresqldata.csv')
for i,r in df.iterrows():
	doc=r.to_json()
	res=es.index(index="frompostgresql", body=doc)
	print(res)
# Out:
# /var/folders/2g/khfzbcm51hj5wtq1k8bww50w0000gn/T/ipykernel_1725/1817559895.py:5: DeprecationWarning: The 'body' parameter is deprecated and will be removed in a future version. Instead use the 'document' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   res=es.index(index="frompostgresql", body=doc)
# {'_index': 'frompostgresql', '_id': 'p1Q1RYsB-SsndkOdZ-Lu', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# {'_index': 'frompostgresql', '_id': 'qFQ1RYsB-SsndkOdaOIt', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# {'_index': 'frompostgresql', '_id': 'qVQ1RYsB-SsndkOdaOI2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# ...

# %% [markdown]
# # langkah-langkah

# %% [markdown]
# - Ambil data dari kaggle, lakukan pembersihan data
# - Simpan data yang telah dibersihkan
# - Load Data ke elasticsearch
# - Masuk ke google crome, buka: http://localhost:5601/
# - Di dalam elasticsearch , scroll kebawah -> pilih stack management
# - Pilih "Data view" yang ada di Kibana
# - Create data view
# - pada bagian index, isi indexnya sesuai dengan codingan python. Misal seperti gambar berikut:
# <img src='irfan.png'>

# %% [markdown]
# - Selanjutnya Masuk ke Dashboard dan buat dashboard
# - Visualisasi:
#     - wordcloud
#     - heatmap
#     - pie chart
#     - bar chart
#     - line chart
#
# - jangan lupa berikan penjelasan di text pada dashboard
